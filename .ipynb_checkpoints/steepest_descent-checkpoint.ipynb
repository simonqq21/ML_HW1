# %%
import sys

# %%
print(sys.executable)
# Out:
# /home/simonque/Documents/code/env/bin/python3

# %%
print(sys.prefix)
# Out:
# /home/simonque/Documents/code/env

# %% [markdown]
# Steepest Descent
# ===================================

# %% [markdown]
# # Import Libraries

# %%
import numpy as np 
import matplotlib.pyplot as plt
import argparse
import csv

# %%
# parser = argparse.ArgumentParser(
#     description = "Perform regularized linear model regression from scratch.")
# parser.add_argument("filepath", type=str, help="Path to the input file")
# parser.add_argument("lambda_val", type=float, help="Lambda value used for LSE and Steepest Descent")
# parser.add_argument("num_polynomial_bases", type=int, help="Number of polynomial bases")
# args = parser.parse_args()

# %% [markdown]
# # Define input filename and parameters

# %%
filename = "input.txt"
lambda_val = 10000
num_polynomial_bases = 3
num_iterations = 500

# %% [markdown]
# # Read the input file and store input data points into a list

# %%
datapoints = []
with open(filename, 'r', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        datapoints.append([float(i) for i in row])
num_datapoints = len(datapoints)
print(f"number of datapoints: {num_datapoints}\n")

datapoints_arr = np.zeros((num_datapoints, 2), dtype=np.float32)

i = 0
for datapoint in datapoints:
    datapoints_arr[i,0] = datapoint[0]
    datapoints_arr[i,1] = datapoint[1]
    i+=1;

print(datapoints_arr)
# Out:
# number of datapoints: 23
#
# [[-5.         51.764053  ]
#  [-4.7959185  45.423065  ]
#  [-4.591837   41.27445   ]
#  [-3.9795918  26.636217  ]
#  [-3.5714285  20.256805  ]
#  [-2.9591837  11.618429  ]
#  [-2.7551022  10.450525  ]
#  [-1.7346939   1.8480983 ]
#  [-1.3265306  -1.040535  ]
#  [-0.9183673  -4.6146307 ]
#  [-0.71428573 -1.3871977 ]
#  [-0.30612245 -1.9916444 ]
#  [ 0.10204082 -0.9129246 ]
#  [ 0.71428573  6.63482   ]
#  [ 1.1224489   9.546867  ]
#  [ 1.7346939  15.720161  ]
#  [ 1.9387755  20.622517  ]
#  [ 2.5510204  33.4806    ]
#  [ 2.9591837  40.76392   ]
#  [ 3.9795918  66.89976   ]
#  [ 4.387755   78.44316   ]
#  [ 4.591837   86.99157   ]
#  [ 5.         99.78726   ]]

# %% [markdown]
# # DIY matrix functions

# %% [markdown]
# ## Matrix Transpose

# %%
def diy_transpose(input_matrix: np.array):
    if len(input_matrix.shape) == 1:
        input_matrix = np.expand_dims(input_matrix, -1)
    transposed_shape = input_matrix.shape[::-1]
    transposed_matrix = np.zeros(shape=transposed_shape, dtype=input_matrix.dtype)
    for i in range(transposed_shape[0]):
        for j in range(transposed_shape[1]):
            transposed_matrix[i,j] = input_matrix[j,i]
    return np.squeeze(transposed_matrix)

# %% [markdown]
# ## Matrix multiplication

# %%
def diy_dot(A: np.array, B: np.array):
    if len(A.shape) == 1:
        A = np.expand_dims(A, 0)
    if len(B.shape) == 1:
        B = np.expand_dims(B, -1)
    # print(A.shape, B.shape)
    
    if (A.shape[1] != B.shape[0]):
        raise ValueError("A and B shapes do not fit for multiplication!")
    else:
        
        
        m = A.shape[0]
        t = A.shape[1]
        n = B.shape[1]
        
        C = np.zeros(shape=(m,n), dtype=A.dtype)
        # for each row in A
        for i in range(m):
            # for each column in B
            for j in range(n):
                for k in range(t):
                    C[i,j] += A[i,k] * B[k,j]
        return np.squeeze(C)

# %% [markdown]
# ## Matrix abs

# %%
def diy_abs(A: np.array):
    A_abs = np.zeros(shape=A.shape, dtype=A.dtype)
    if len(A.shape) == 1:
        for i in range(A.shape[0]):
            if A[i] < 0:
                A_abs[i] = A[i] * -1
            else:
                A_abs[i] = A[i]
    else:
        for i in range(A.shape[0]):
            A[i] = diy_abs(A[i])
            
    return A_abs

# %% [markdown]
# ## Matrix sum

# %%
def diy_sum(A:np.array):
    sum = 0
    if len(A.shape) == 1:
        for i in range(A.shape[0]):
            sum += A[i]
    else:
        for i in range(A.shape[0]):
            sum += diy_sum(A[i])
    return sum

# %% [markdown]
# ## DIY argmax

# %%
def diy_argmax(A:np.array):
    argmax = 0
    if len(A.shape) == 1:
        maxval = A[0]
        for i in range(A.shape[0]):
            if A[i] > maxval:
               argmax = i 
    else:
        argmax = diy_argmax(A[i])
    return argmax

# %% [markdown]
# ## DIY sign

# %%
def diy_sign(A: np.array):
    A_sign = A.flatten()
    for i in range(A_sign.shape[0]):
        if A_sign[i] > 0:
            A_sign[i] = 1
        elif A_sign[i] < 0:
            A_sign[i] = -1
        else:
            A_sign[i] = 0
    A_sign = np.reshape(A_sign, A.shape)
    return A_sign

# %% [markdown]
# # Steepest Descent

# %% [markdown]
# ## Create A and b

# %%
b = np.zeros((num_datapoints), dtype=np.float32)
b = datapoints_arr[:,1]
    
A = np.zeros((num_datapoints, num_polynomial_bases), dtype=np.float32)
for basis in range(num_polynomial_bases):
    A[:,basis] = datapoints_arr[:,0] ** basis

# %%
A
# Out:
# array([[ 1.0000000e+00, -5.0000000e+00,  2.5000000e+01],
#        [ 1.0000000e+00, -4.7959185e+00,  2.3000834e+01],
#        [ 1.0000000e+00, -4.5918369e+00,  2.1084967e+01],
#        [ 1.0000000e+00, -3.9795918e+00,  1.5837152e+01],
#        [ 1.0000000e+00, -3.5714285e+00,  1.2755102e+01],
#        [ 1.0000000e+00, -2.9591837e+00,  8.7567682e+00],
#        [ 1.0000000e+00, -2.7551022e+00,  7.5905881e+00],
#        [ 1.0000000e+00, -1.7346939e+00,  3.0091629e+00],
#        [ 1.0000000e+00, -1.3265306e+00,  1.7596834e+00],
#        [ 1.0000000e+00, -9.1836733e-01,  8.4339857e-01],
#        [ 1.0000000e+00, -7.1428573e-01,  5.1020408e-01],
#        [ 1.0000000e+00, -3.0612245e-01,  9.3710959e-02],
#        [ 1.0000000e+00,  1.0204082e-01,  1.0412329e-02],
#        [ 1.0000000e+00,  7.1428573e-01,  5.1020408e-01],
#        [ 1.0000000e+00,  1.1224489e+00,  1.2598916e+00],
#        [ 1.0000000e+00,  1.7346939e+00,  3.0091629e+00],
#        [ 1.0000000e+00,  1.9387755e+00,  3.7588506e+00],
#        [ 1.0000000e+00,  2.5510204e+00,  6.5077052e+00],
#        [ 1.0000000e+00,  2.9591837e+00,  8.7567682e+00],
#        [ 1.0000000e+00,  3.9795918e+00,  1.5837152e+01],
#        [ 1.0000000e+00,  4.3877549e+00,  1.9252394e+01],
#        [ 1.0000000e+00,  4.5918369e+00,  2.1084967e+01],
#        [ 1.0000000e+00,  5.0000000e+00,  2.5000000e+01]], dtype=float32)

# %%
b
# Out:
# array([51.764053 , 45.423065 , 41.27445  , 26.636217 , 20.256805 ,
#        11.618429 , 10.450525 ,  1.8480983, -1.040535 , -4.6146307,
#        -1.3871977, -1.9916444, -0.9129246,  6.63482  ,  9.546867 ,
#        15.720161 , 20.622517 , 33.4806   , 40.76392  , 66.89976  ,
#        78.44316  , 86.99157  , 99.78726  ], dtype=float32)

# %% [markdown]
# ## Define learning rate

# %%
learning_rate = 0.0001

# %% [markdown]
# ## Initialize weights, biases

# %%
x = np.zeros(shape=num_polynomial_bases, dtype=np.float32)
# x = np.array([-0.2314002,  4.90619  ,  3.0238533])

# %% [markdown]
# ## Define error function

# %%
def compute_error(A, x, b):
    Ax = diy_dot(A, x)
    
    error = diy_sum(diy_abs(Ax - b) ** 2)
    return error

# %% [markdown]
# ## Get the LSE gradient

# %%
A_t = diy_transpose(A)
A.shape, A_t.shape
# Out:
# ((23, 3), (3, 23))

# %%
learning_rate = 1e-4

# %%
x_t = diy_transpose(x)
print(x_t.shape)
AtA = diy_dot(A_t, A)
print(AtA.shape)
# Out:
# (3,)
# (3, 3)

# %%
x_t = np.transpose(x)
print(x_t.shape)
AtA = diy_dot(A_t, A)
print(AtA.shape)
# Out:
# (3,)
# (3, 3)

# %%
for i in range(num_iterations):
    x_t = diy_transpose(x)
    grad = 2 * (diy_dot(x_t, diy_dot(A_t, A))-diy_dot(A_t, b)) 
    # grad[1:] += lambda_val * x[1:] # L2 regularization
    grad[1:] += lambda_val * diy_sign(x[1:]) # L1 regularization
    # print(x)
    # print(diy_abs(grad))
    # print(np.abs(grad))
    # print(np.argmax(diy_abs(grad)))
    e = np.zeros(shape=x.shape)
    e[diy_argmax(diy_abs(grad))] = 1
    # print(e)
    grad = grad * e
    error = compute_error(A, x, b)
    print(f"Total error: {error}")
    x = x - learning_rate * grad
# Out:
# Total error: 39587.05859375
# Total error: 6799.41748046875
# Total error: 10413.1796875
# Total error: 11410.9619140625
# Total error: 11009.75390625
# Total error: 12716.658203125
# Total error: 10231.201171875
# Total error: 11824.58984375
# Total error: 9591.56640625
# Total error: 11075.240234375
# Total error: 12790.880859375
# Total error: 10285.037109375
# Total error: 11886.912109375
# Total error: 9635.76953125
# Total error: 11127.611328125
# Total error: 12850.16015625
# Total error: 10328.0966796875
# Total error: 11936.6826171875
# Total error: 9671.126953125
# Total error: 11169.4345703125
# Total error: 12897.4453125
# Total error: 10362.4833984375
# Total error: 11976.3828125
# Total error: 9699.365234375
# Total error: 11202.79296875
# Total error: 12935.130859375
# Total error: 10389.9130859375
# Total error: 12008.0234375
# Total error: 9721.8916015625
# Total error: 11229.3779296875
# Total error: 12965.14453125
# Total error: 10411.7734375
# Total error: 12033.21875
# Total error: 9739.845703125
# Total error: 11250.546875
# Total error: 12989.03125
# Total error: 10429.18359375
# Total error: 12053.271484375
# Total error: 9754.1435546875
# Total error: 11267.396484375
# Total error: 13008.03515625
# Total error: 10443.037109375
# Total error: 12069.2265625
# Total error: 9765.5234375
# Total error: 11280.7998046875
# Total error: 13023.1494140625
# Total error: 10454.060546875
# Total error: 12081.9130859375
# Total error: 9774.576171875
# Total error: 11291.4599609375
# Total error: 13035.1650390625
# Total error: 10462.8271484375
# Total error: 12092.0
# Total error: 9781.7763671875
# Total error: 11299.9345703125
# Total error: 13044.7158203125
# Total error: 10469.7958984375
# Total error: 12100.017578125
# Total error: 9787.5009765625
# Total error: 11306.669921875
# Total error: 13052.3056640625
# Total error: 10475.3349609375
# Total error: 12106.3896484375
# Total error: 9792.05078125
# Total error: 11312.0234375
# Total error: 13058.337890625
# Total error: 10479.73828125
# Total error: 12111.453125
# Total error: 9795.6669921875
# Total error: 11316.27734375
# Total error: 13063.12890625
# Total error: 10483.236328125
# Total error: 12115.4755859375
# Total error: 9798.541015625
# Total error: 11319.6572265625
# Total error: 13066.935546875
# Total error: 10486.015625
# Total error: 12118.671875
# Total error: 9800.822265625
# Total error: 11322.341796875
# Total error: 13069.9599609375
# Total error: 10488.2236328125
# Total error: 12121.208984375
# Total error: 9802.63671875
# Total error: 11324.474609375
# Total error: 13072.361328125
# Total error: 10489.9775390625
# Total error: 12123.2265625
# Total error: 9804.078125
# Total error: 11326.16796875
# Total error: 13074.2705078125
# Total error: 10491.37109375
# Total error: 12124.828125
# Total error: 9805.2216796875
# Total error: 11327.5146484375
# Total error: 13075.7861328125
# Total error: 10492.478515625
# Total error: 12126.099609375
# Total error: 9806.130859375
# Total error: 11328.58203125
# Total error: 13076.990234375
# Total error: 10493.3564453125
# Total error: 12127.111328125
# Total error: 9806.853515625
# Total error: 11329.431640625
# Total error: 13077.9453125
# Total error: 10494.0546875
# Total error: 12127.9130859375
# Total error: 9807.427734375
# Total error: 11330.10546875
# Total error: 13078.7041015625
# Total error: 10494.609375
# Total error: 12128.55078125
# Total error: 9807.8818359375
# Total error: 11330.6416015625
# Total error: 13079.30859375
# Total error: 10495.0498046875
# Total error: 12129.056640625
# Total error: 9808.244140625
# Total error: 11331.06640625
# Total error: 13079.787109375
# Total error: 10495.3994140625
# Total error: 12129.458984375
# Total error: 9808.53125
# Total error: 11331.404296875
# Total error: 13080.1669921875
# Total error: 10495.6767578125
# Total error: 12129.7783203125
# Total error: 9808.759765625
# Total error: 11331.6728515625
# Total error: 13080.46875
# Total error: 10495.8984375
# Total error: 12130.0322265625
# Total error: 9808.9404296875
# Total error: 11331.8857421875
# Total error: 13080.7099609375
# Total error: 10496.072265625
# Total error: 12130.2333984375
# Total error: 9809.0849609375
# Total error: 11332.0546875
# Total error: 13080.8994140625
# Total error: 10496.212890625
# Total error: 12130.3935546875
# Total error: 9809.19921875
# Total error: 11332.189453125
# Total error: 13081.05078125
# Total error: 10496.322265625
# Total error: 12130.521484375
# Total error: 9809.2900390625
# Total error: 11332.294921875
# Total error: 13081.171875
# Total error: 10496.41015625
# Total error: 12130.62109375
# Total error: 9809.3623046875
# Total error: 11332.380859375
# Total error: 13081.2666015625
# Total error: 10496.48046875
# Total error: 12130.701171875
# Total error: 9809.4189453125
# Total error: 11332.4482421875
# Total error: 13081.3427734375
# Total error: 10496.53515625
# Total error: 12130.7646484375
# Total error: 9809.4638671875
# Total error: 11332.5009765625
# Total error: 13081.4033203125
# Total error: 10496.580078125
# Total error: 12130.8154296875
# Total error: 9809.5009765625
# Total error: 11332.5439453125
# Total error: 13081.451171875
# Total error: 10496.6142578125
# Total error: 12130.85546875
# Total error: 9809.529296875
# Total error: 11332.578125
# Total error: 13081.4892578125
# Total error: 10496.6416015625
# Total error: 12130.8876953125
# Total error: 9809.5517578125
# Total error: 11332.6044921875
# Total error: 13081.5185546875
# Total error: 10496.6640625
# Total error: 12130.9130859375
# Total error: 9809.5703125
# Total error: 11332.6259765625
# Total error: 13081.54296875
# Total error: 10496.6826171875
# Total error: 12130.93359375
# Total error: 9809.5849609375
# Total error: 11332.642578125
# Total error: 13081.5615234375
# Total error: 10496.6962890625
# Total error: 12130.94921875
# Total error: 9809.595703125
# Total error: 11332.65625
# Total error: 13081.5771484375
# Total error: 10496.70703125
# Total error: 12130.9609375
# Total error: 9809.6044921875
# Total error: 11332.6669921875
# Total error: 13081.5888671875
# Total error: 10496.71484375
# Total error: 12130.9716796875
# Total error: 9809.6123046875
# Total error: 11332.67578125
# Total error: 13081.599609375
# Total error: 10496.72265625
# Total error: 12130.98046875
# Total error: 9809.6171875
# Total error: 11332.681640625
# Total error: 13081.60546875
# Total error: 10496.7275390625
# Total error: 12130.986328125
# Total error: 9809.623046875
# Total error: 11332.6875
# Total error: 13081.6123046875
# Total error: 10496.732421875
# Total error: 12130.9912109375
# Total error: 9809.6259765625
# Total error: 11332.69140625
# Total error: 13081.6171875
# Total error: 10496.736328125
# Total error: 12130.994140625
# Total error: 9809.6298828125
# Total error: 11332.6953125
# Total error: 13081.619140625
# Total error: 10496.73828125
# Total error: 12130.998046875
# Total error: 9809.630859375
# Total error: 11332.697265625
# Total error: 13081.623046875
# Total error: 10496.7412109375
# Total error: 12131.0
# Total error: 9809.6328125
# Total error: 11332.69921875
# Total error: 13081.6259765625
# Total error: 10496.7421875
# Total error: 12131.0029296875
# Total error: 9809.634765625
# Total error: 11332.701171875
# Total error: 13081.626953125
# Total error: 10496.744140625
# Total error: 12131.00390625
# Total error: 9809.6357421875
# Total error: 11332.703125
# Total error: 13081.62890625
# Total error: 10496.7451171875
# Total error: 12131.005859375
# Total error: 9809.63671875
# Total error: 11332.7041015625
# Total error: 13081.630859375
# Total error: 10496.74609375
# Total error: 12131.0068359375
# Total error: 9809.63671875
# Total error: 11332.7041015625
# Total error: 13081.630859375
# Total error: 10496.7470703125
# Total error: 12131.0078125
# Total error: 9809.6376953125
# Total error: 11332.7060546875
# Total error: 13081.6328125
# Total error: 10496.7470703125
# Total error: 12131.0078125
# Total error: 9809.6376953125
# Total error: 11332.7060546875
# Total error: 13081.6328125
# Total error: 10496.748046875
# Total error: 12131.0078125
# Total error: 9809.638671875
# Total error: 11332.70703125
# Total error: 13081.6328125
# Total error: 10496.748046875
# Total error: 12131.0087890625
# Total error: 9809.638671875
# Total error: 11332.70703125
# Total error: 13081.6337890625
# Total error: 10496.748046875
# Total error: 12131.0087890625
# Total error: 9809.6396484375
# Total error: 11332.70703125
# Total error: 13081.6337890625
# Total error: 10496.748046875
# Total error: 12131.009765625
# Total error: 9809.6396484375
# Total error: 11332.70703125
# Total error: 13081.6337890625
# Total error: 10496.748046875
# Total error: 12131.009765625
# Total error: 9809.6396484375
# Total error: 11332.70703125
# Total error: 13081.634765625
# Total error: 10496.748046875
# Total error: 12131.009765625
# Total error: 9809.6396484375
# Total error: 11332.70703125
# Total error: 13081.634765625
# Total error: 10496.748046875
# Total error: 12131.009765625
# Total error: 9809.638671875
# Total error: 11332.70703125
# Total error: 13081.634765625
# Total error: 10496.748046875
# Total error: 12131.009765625
# Total error: 9809.6396484375
# Total error: 11332.70703125
# Total error: 13081.634765625
# Total error: 10496.748046875
# Total error: 12131.009765625
# Total error: 9809.6396484375
# Total error: 11332.70703125
# Total error: 13081.634765625
# Total error: 10496.748046875
# Total error: 12131.0107421875
# Total error: 9809.6396484375
# Total error: 11332.70703125
# Total error: 13081.634765625
# Total error: 10496.748046875
# Total error: 12131.0107421875
# Total error: 9809.6396484375
# Total error: 11332.70703125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.0107421875
# Total error: 9809.6396484375
# Total error: 11332.70703125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.0107421875
# Total error: 9809.6396484375
# Total error: 11332.70703125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.0107421875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.0107421875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.0107421875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125
# Total error: 13081.634765625
# Total error: 10496.7490234375
# Total error: 12131.01171875
# Total error: 9809.6396484375
# Total error: 11332.7080078125

# %%
x
# Out:
# array([ 0.        , -0.76035847,  1.69982515])

# %% [markdown]
# ## Calculate the total error

# %%
# regressed_y_vals = np.zeros(shape=(num_datapoints), dtype=np.float32)
# for d_idx in range(num_datapoints):
#     for basis in range(num_polynomial_bases):
#         regressed_y_vals[d_idx] += x[basis] * datapoints_arr[d_idx,0] ** basis
# regressed_y_vals

# %%
def compute_error(A, x, b):
    Ax = diy_dot(A, x)
    
    error = diy_sum(diy_abs(Ax - b) ** 2)
    return error

# %%
error = compute_error(A, x, b)
print(f"Total error: {error}")
# Out:
# Total error: 13081.634765625

# %% [markdown]
# # Print equation of curve

# %%
equation = ""
if x[-1] < -1:
    equation += "-"
for i in range(num_polynomial_bases-1,-1,-1):
    equation += f"{abs(x[i]):.8f} "
    if i > 0:
        equation += f"x ^ {i} "
        if x[i-1] < 0:
            equation += "- "
        else:
            equation += "+ "
print(f"Curve of best fit: {equation}")
# Out:
# Curve of best fit: 1.69982515 x ^ 2 - 0.76035847 x ^ 1 + 0.00000000

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import math

# %%
'''
Function to visualize the datapoints and the regressed trendline
'''
def plot_datapoints_trendline(datapoints_arr: np.array, 
                              num_bases: int,
                              lambda_val: float,
                              equation: str,
                                error: float,
                             filename: str):
    # get min and max x and y values of the sample data 
    min_x = np.min(datapoints_arr[:,0])
    max_x = np.max(datapoints_arr[:,0])
    min_y = np.min(datapoints_arr[:,1])
    max_y = np.max(datapoints_arr[:,1])
    x_bounds = (math.floor(min_x - 1), math.ceil(max_x + 1))
    y_bounds = (math.floor(min_y - 1), math.ceil(max_y + 1))

    fig,ax = plt.subplots(figsize = (10,6))
    # set limits
    ax.set_xlim(x_bounds[0], x_bounds[1])
    ax.set_ylim(y_bounds[0], y_bounds[1])
    # plot curve
    curve_x = np.linspace(min_x, max_x, 1000)
    curve_y = 0
    for i in range(num_bases):
        curve_y += x[i] * curve_x ** i
    ax.plot(curve_x, curve_y, label="trendline", color=((0.0,0.0, 1.0)))
    # plot points
    ax.scatter(datapoints_arr[:,0], datapoints_arr[:,1], label="datapoints", s=80, c=[[1.0,0.0, 0.0]], marker="X")
    ax.text(min_x - 0.5, max_y-15, f"equation = {equation}")
    ax.text(min_x - 0.5, max_y-20, f"no. datapoints = {datapoints_arr.shape[0]}")
    ax.text(min_x - 0.5, max_y-25, f"num_bases = {num_bases}")
    ax.text(min_x - 0.5, max_y-30, f"lambda = {lambda_val}")
    ax.text(min_x - 0.5, max_y-35, f"error = {error:.4f}")
    ax.legend(loc="upper left")
    plt.title(filename,fontsize=16, fontweight='bold')
    fig.savefig(filename)
    plt.show()

# %%
plot_datapoints_trendline(datapoints_arr, 
                          num_polynomial_bases, 
                          lambda_val,
                          equation,
                          error,
                          f"steepest_descent_{num_polynomial_bases}_{lambda_val}.png")
